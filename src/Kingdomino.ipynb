# %%
class StartingTile:
    def __init__(self):
        self.is_starting_tile = True

class Player:
    def __init__(self):
        self.kingdom = [[None for _ in range(5)] for _ in range(5)]  # Grille 5x5
        self.starting_tile = StartingTile()  # Tuile de départ
        self.kingdom[2][2] = self.starting_tile  # Placer la tuile de départ au centre

class KingdominoGame:
  def __init__(self, players):
        self.players = players
        self.draw_pile = self.create_draw_pile()  # Créez une pile de tuiles mélangées
        self.current_turn = 0

  def create_draw_pile():
      tiles = [
          Tile(1, ['Champ', 'Champ'], [0, 0]), Tile(2, ['Champ', 'Champ'], [0, 0]),
          Tile(3, ['Forêt', 'Forêt'], [0, 0]), Tile(4, ['Forêt', 'Forêt'], [0, 0]),
          Tile(5, ['Forêt', 'Forêt'], [0, 0]), Tile(6, ['Forêt', 'Forêt'], [0, 0]),
          Tile(7, ['Lac', 'Lac'], [0, 0]), Tile(8, ['Lac', 'Lac'], [0, 0]),
          Tile(9, ['Lac', 'Lac'], [0, 0]), Tile(10, ['Prairie', 'Prairie'], [0, 0]),
          Tile(11, ['Prairie', 'Prairie'], [0, 0]), Tile(12, ['Marécage', 'Marécage'], [0, 0]),
          Tile(13, ['Champ', 'Forêt'], [0, 0]), Tile(14, ['Champ', 'Lac'], [0, 0]),
          Tile(15, ['Champ', 'Prairie'], [0, 0]), Tile(16, ['Prairie', 'Marécage'], [0, 0]),
          Tile(17, ['Forêt', 'Lac'], [0, 0]), Tile(18, ['Forêt', 'Prairie'], [0, 0]),
          Tile(19, ['Champ', 'Forêt'], [1, 0]), Tile(20, ['Champ', 'Lac'], [1, 0]),
          Tile(21, ['Champ', 'Prairie'], [1, 0]), Tile(22, ['Champ', 'Marécage'], [1, 0]),
          Tile(23, ['Champ', 'Mine'], [1, 0]), Tile(24, ['Forêt', 'Champ'], [1, 0]),
          Tile(25, ['Forêt', 'Champ'], [1, 0]), Tile(26, ['Forêt', 'Champ'], [1, 0]),
          Tile(27, ['Forêt', 'Champ'], [1, 0]), Tile(28, ['Forêt', 'Lac'], [1, 0]),
          Tile(29, ['Forêt', 'Prairie'], [1, 0]), Tile(30, ['Lac', 'Champ'], [1, 0]),
          Tile(31, ['Lac', 'Champ'], [1, 0]), Tile(32, ['Lac', 'Forêt'], [1, 0]),
          Tile(33, ['Lac', 'Forêt'], [1, 0]), Tile(34, ['Lac', 'Forêt'], [1, 0]),
          Tile(35, ['Lac', 'Forêt'], [1, 0]), Tile(36, ['Champ', 'Prairie'], [0, 1]),
          Tile(37, ['Lac', 'Prairie'], [0, 1]), Tile(38, ['Champ', 'Marécage'], [1, 0]),
          Tile(39, ['Prairie', 'Marécage'], [0, 0]), Tile(40, ['Mine', 'Champ'], [1, 0]),
          Tile(41, ['Champ', 'Prairie'], [0, 2]), Tile(42, ['Lac', 'Prairie'], [0, 2]),
          Tile(43, ['Champ', 'Marécage'], [0, 2]), Tile(44, ['Prairie', 'Marécage'], [0, 2]),
          Tile(45, ['Mine', 'Champ'], [2, 0]), Tile(46, ['Marécage', 'Mine'], [0, 2]),
          Tile(47, ['Marécage', 'Mine'], [0, 2]), Tile(48, ['Champ', 'Mine'], [0, 3])
      ]
      random.shuffle(tiles)
      return tiles
